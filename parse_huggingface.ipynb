# %%
from langchain_openai import ChatOpenAI
import os
from langchain_core.output_parsers import StrOutputParser
os.environ["HTTP_PROXY"] = "http://127.0.0.1:8890"
os.environ["HTTPS_PROXY"] = "http://127.0.0.1:8890"
# ucloud api key
API_KEY = os.getenv("UCLOUD_API_KEY")
API_BASE = "https://api.modelverse.cn/v1"
model = ChatOpenAI(
    openai_api_key=API_KEY,
    openai_api_base=API_BASE,
    model="deepseek-ai/DeepSeek-V3-0324")
output_parser = StrOutputParser()

# %%
from langchain_core.documents import Document
from langchain_community.document_loaders import DirectoryLoader, TextLoader

loader = DirectoryLoader(
    "HuggingFace/",
    loader_cls=lambda path: TextLoader(path, encoding="utf-8")
)
docs = loader.load()

docs
# Out:
# [Document(metadata={'source': 'HuggingFace\\agibot-world_results.txt'}, page_content='**agibot-world/AgiBotWorld-Beta**  \n分类：数据集  \nlike数：34  \ndownload数：37482  \n最后更新时间：2025-04-12T08:41:06.000Z  \nurl: https://huggingface.co/datasets/agibot-world/AgiBotWorld-Beta  \n\n**agibot-world/AgiBotWorld-Alpha**  \n分类：数据集  \nlike数：198  \ndownload数：5777  \n最后更新时间：2025-07-10T11:49:26.000Z  \nurl: https://huggingface.co/datasets/agibot-world/AgiBotWorld-Alpha  \n\n**agibot-world/AgiBotWorldChallenge-2025**  \n分类：数据集  \nlike数：17  \ndownload数：6432  \n最后更新时间：2025-08-29T03:13:25.000Z  \nurl: https://huggingface.co/datasets/agibot-world/AgiBotWorldChallenge-2025  \n\n**agibot-world/AgiBotDigitalWorld**  \n分类：数据集  \nlike数：34  \ndownload数：5311  \n最后更新时间：2025-02-27T01:38:57.000Z  \nurl: https://huggingface.co/datasets/agibot-world/AgiBotDigitalWorld  \n\n**agibot-world/GenieSimAssets**  \n分类：数据集  \nlike数：12  \ndownload数：2220  \n最后更新时间：2025-07-14T12:38:00.000Z  \nurl: https://huggingface.co/datasets/agibot-world/GenieSimAssets  \n\n**agibot-world/EWMBench**  \n分类：数据集  \nlike数：0  \ndownload数：230  \n最后更新时间：2025-05-16T03:59:50.000Z  \nurl: https://huggingface.co/datasets/agibot-world/EWMBench  \n\n'),
#  Document(metadata={'source': 'HuggingFace\\ECNU-CILab_results.txt'}, page_content='**ECNU-CILab/ArtAug-lora-FLUX.1dev-v1**\n分类：模型\nlike数：8\ndownload数：95\n最后更新时间：None\nurl: https://huggingface.co/ECNU-CILab/ArtAug-lora-FLUX.1dev-v1\n\n**ECNU-CILab/ExVideo-SVD-128f-v1**\n分类：模型\nlike数：61\ndownload数：0\n最后更新时间：None\nurl: https://huggingface.co/ECNU-CILab/ExVideo-SVD-128f-v1\n'),
#  Document(metadata={'source': 'HuggingFace\\FourierIntelligence_results.txt'}, page_content='**FourierIntelligence/ActionNet**  \n分类：数据集  \nlike数：6  \ndownload数：1540  \n最后更新时间：2025-08-25T02:36:02.000Z  \nurl: https://huggingface.co/datasets/FourierIntelligence/ActionNet  \n'),
#  Document(metadata={'source': 'HuggingFace\\fudan-generative-ai_results.txt'}, page_content='**fudan-generative-ai/champ_trainning_sample**  \n分类：数据集  \nlike数：6  \ndownload数：978  \n最后更新时间：2024-06-04T01:15:34.000Z  \nurl: https://huggingface.co/fudan-generative-ai/champ_trainning_sample  \n\n**fudan-generative-ai/champ_motions_example**  \n分类：数据集  \nlike数：2  \ndownload数：337  \n最后更新时间：2024-04-19T02:30:00.000Z  \nurl: https://huggingface.co/fudan-generative-ai/champ_motions_example  \n\n**fudan-generative-ai/hallo3_training_data**  \n分类：数据集  \nlike数：7  \ndownload数：123  \n最后更新时间：2025-04-15T06:00:47.000Z  \nurl: https://huggingface.co/fudan-generative-ai/hallo3_training_data  \n\n**fudan-generative-ai/hallo2**  \n分类：模型  \nlike数：129  \ndownload数：0  \n最后更新时间：None  \nurl: https://huggingface.co/fudan-generative-ai/hallo2  \n\n**fudan-generative-ai/hallo**  \n分类：模型  \nlike数：96  \ndownload数：0  \n最后更新时间：None  \nurl: https://huggingface.co/fudan-generative-ai/hallo  \n\n**fudan-generative-ai/hallo3**  \n分类：模型  \nlike数：62  \ndownload数：0  \n最后更新时间：None  \nurl: https://huggingface.co/fudan-generative-ai/hallo3  '),
#  Document(metadata={'source': 'HuggingFace\\Infinigence_results.txt'}, page_content='**Infinigence/LVEval**  \n分类：数据集  \nlike数：13  \ndownload数：4637  \n最后更新时间：2024-02-10T08:17:11.000Z  \nurl: https://huggingface.co/Infinigence/LVEval  \n\n**Infinigence/Megrez-3B-Instruct**  \n分类：模型  \nlike数：32  \ndownload数：1199  \n最后更新时间：None  \nurl: https://huggingface.co/Infinigence/Megrez-3B-Instruct  \n\n**Infinigence/Megrez-3B-Omni**  \n分类：模型  \nlike数：134  \ndownload数：18  \n最后更新时间：None  \nurl: https://huggingface.co/Infinigence/Megrez-3B-Omni  \n\n'),
#  Document(metadata={'source': 'HuggingFace\\infly_results.txt'}, page_content='**infly/inf-retriever-v1**\n分类：模型\nlike数：37\ndownload数：15612\n最后更新时间：None\nurl: https://huggingface.co/infly/inf-retriever-v1\n\n**infly/inf-retriever-v1-1.5b**\n分类：模型\nlike数：42\ndownload数：5996\n最后更新时间：None\nurl: https://huggingface.co/infly/inf-retriever-v1-1.5b\n\n**infly/INF-ORM-Llama3.1-70B**\n分类：模型\nlike数：26\ndownload数：3027\n最后更新时间：None\nurl: https://huggingface.co/infly/INF-ORM-Llama3.1-70B\n\n**infly/OpenCoder-8B-Instruct**\n分类：模型\nlike数：196\ndownload数：1666\n最后更新时间：None\nurl: https://huggingface.co/infly/OpenCoder-8B-Instruct\n\n**infly/OpenCoder-1.5B-Instruct**\n分类：模型\nlike数：42\ndownload数：1228\n最后更新时间：None\nurl: https://huggingface.co/infly/OpenCoder-1.5B-Instruct\n\n**infly/OpenCoder-1.5B-Base**\n分类：模型\nlike数：22\ndownload数：1176\n最后更新时间：None\nurl: https://huggingface.co/infly/OpenCoder-1.5B-Base\n\n**infly/OpenCoder-8B-Base**\n分类：模型\nlike数：28\ndownload数：1166\n最后更新时间：None\nurl: https://huggingface.co/infly/OpenCoder-8B-Base\n\n**infly/inf-wse-v2-base-zh**\n分类：模型\nlike数：3\ndownload数：834\n最后更新时间：None\nurl: https://huggingface.co/infly/inf-wse-v2-base-zh\n\n**infly/Infinity-Doc-55K**\n分类：数据集\nlike数：6\ndownload数：172\n最后更新时间：2025-06-30T05:24:10.000Z\nurl: https://huggingface.co/infly/Infinity-Doc-55K\n\n**infly/inf-rl-qwen-coder-32b-2746**\n分类：模型\nlike数：2\ndownload数：155\n最后更新时间：None\nurl: https://huggingface.co/infly/inf-rl-qwen-coder-32b-2746\n\n**infly/INF-ORM-Preference-Magnitude-80K**\n分类：数据集\nlike数：9\ndownload数：102\n最后更新时间：2024-12-05T17:44:28.000Z\nurl: https://huggingface.co/infly/INF-ORM-Preference-Magnitude-80K\n\n**infly/inf-o1-pi0**\n分类：模型\nlike数：8\ndownload数：52\n最后更新时间：None\nurl: https://huggingface.co/infly/inf-o1-pi0'),
#  Document(metadata={'source': 'HuggingFace\\MemTensor_results.txt'}, page_content='**MemTensor/MemOperator-0.6B**  \n分类：模型（如大语言模型，多模态模型等）  \nlike数：1  \ndownload数：193  \n最后更新时间：None  \nurl: https://huggingface.co/MemTensor/MemOperator-0.6B  \n\n'),
#  Document(metadata={'source': 'HuggingFace\\MiniMaxAI_results.txt'}, page_content='**MiniMaxAI/MiniMax-VL-01**  \n分类：模型  \nlike数：277  \ndownload数：103864  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/MiniMax-VL-01  \n\n**MiniMaxAI/MiniMax-Text-01**  \n分类：模型  \nlike数：644  \ndownload数：3423  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/MiniMax-Text-01  \n\n**MiniMaxAI/MiniMax-Text-01-hf**  \n分类：模型  \nlike数：6  \ndownload数：16497  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/MiniMax-Text-01-hf  \n\n**MiniMaxAI/MiniMax-M1-40k**  \n分类：模型  \nlike数：175  \ndownload数：26365  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/MiniMax-M1-40k  \n\n**MiniMaxAI/MiniMax-M1-80k**  \n分类：模型  \nlike数：671  \ndownload数：994  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/MiniMax-M1-80k  \n\n**MiniMaxAI/TTS-Multilingual-Test-Set**  \n分类：数据集  \nlike数：21  \ndownload数：515  \n最后更新时间：2025-05-23T11:36:14.000Z  \nurl: https://huggingface.co/MiniMaxAI/TTS-Multilingual-Test-Set  \n\n**MiniMaxAI/SynLogic**  \n分类：数据集  \nlike数：92  \ndownload数：477  \n最后更新时间：2025-07-02T08:58:23.000Z  \nurl: https://huggingface.co/MiniMaxAI/SynLogic  \n\n**MiniMaxAI/SynLogic-7B**  \n分类：模型  \nlike数：20  \ndownload数：134  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/SynLogic-7B  \n\n**MiniMaxAI/SynLogic-Mix-3-32B**  \n分类：模型  \nlike数：12  \ndownload数：114  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/SynLogic-Mix-3-32B  \n\n**MiniMaxAI/MR-NIAH**  \n分类：数据集  \nlike数：3  \ndownload数：121  \n最后更新时间：2025-03-08T08:14:40.000Z  \nurl: https://huggingface.co/MiniMaxAI/MR-NIAH  \n\n**MiniMaxAI/SynLogic-32B**  \n分类：模型  \nlike数：11  \ndownload数：104  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/SynLogic-32B  \n\n**MiniMaxAI/MiniMax-M1-80k-hf**  \n分类：模型  \nlike数：3  \ndownload数：101  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/MiniMax-M1-80k-hf  \n\n**MiniMaxAI/MiniMax-M1-40k-hf**  \n分类：模型  \nlike数：5  \ndownload数：65  \n最后更新时间：None  \nurl: https://huggingface.co/MiniMaxAI/MiniMax-M1-40k-hf  \n\n'),
#  Document(metadata={'source': 'HuggingFace\\OpenGVLab_results.txt'}, page_content='**OpenGVLab/InternVL2_5-26B**  \n分类：模型  \nlike数：31  \ndownload数：193035  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2_5-26B  \n\n**OpenGVLab/InternVL3-14B**  \n分类：模型  \nlike数：73  \ndownload数：933553  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3-14B  \n\n**OpenGVLab/InternVL2-2B**  \n分类：模型  \nlike数：73  \ndownload数：939404  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2-2B  \n\n**OpenGVLab/InternVL3-38B**  \n分类：模型  \nlike数：42  \ndownload数：178735  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3-38B  \n\n**OpenGVLab/InternVL3-1B**  \n分类：模型  \nlike数：72  \ndownload数：85243  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3-1B  \n\n**OpenGVLab/InternVL3-78B**  \n分类：模型  \nlike数：216  \ndownload数：441658  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3-78B  \n\n**OpenGVLab/InternVL3-8B**  \n分类：模型  \nlike数：95  \ndownload数：287542  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3-8B  \n\n**OpenGVLab/InternVL2-1B**  \n分类：模型  \nlike数：77  \ndownload数：189558  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2-1B  \n\n**OpenGVLab/InternVL3-2B**  \n分类：模型  \nlike数：36  \ndownload数：49399  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3-2B  \n\n**OpenGVLab/InternVL3_5-4B-AWQ**  \n分类：模型  \nlike数：7  \ndownload数：156138  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3_5-4B-AWQ  \n\n**OpenGVLab/InternVL2-8B**  \n分类：模型  \nlike数：177  \ndownload数：37271  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2-8B  \n\n**OpenGVLab/InternVL2_5-2B**  \n分类：模型  \nlike数：29  \ndownload数：41163  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2_5-2B  \n\n**OpenGVLab/InternVL2_5-4B**  \n分类：模型  \nlike数：52  \ndownload数：47375  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2_5-4B  \n\n**OpenGVLab/InternVL2_5-8B**  \n分类：模型  \nlike数：93  \ndownload数：34893  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2_5-8B  \n\n**OpenGVLab/InternViT-300M-448px-V2_5**  \n分类：模型  \nlike数：44  \ndownload数：42806  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternViT-300M-448px-V2_5  \n\n**OpenGVLab/InternVideo2_5_Chat_8B**  \n分类：模型  \nlike数：82  \ndownload数：29344  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B  \n\n**OpenGVLab/InternVL2-40B**  \n分类：模型  \nlike数：94  \ndownload数：12448  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2-40B  \n\n**OpenGVLab/InternVL2_5-1B**  \n分类：模型  \nlike数：61  \ndownload数：16673  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2_5-1B  \n\n**OpenGVLab/InternVL3_5-30B-A3B**  \n分类：模型  \nlike数：31  \ndownload数：23024  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2_5-1B  \n\n**OpenGVLab/pvt_v2_b0**  \n分类：模型  \nlike数：2  \ndownload数：24321  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/pvt_v2_b0  \n\n**OpenGVLab/InternVL2-26B**  \n分类：模型  \nlike数：118  \ndownload数：23989  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2-26B  \n\n**OpenGVLab/InternVL2-4B**  \n分类：模型  \nlike数：53  \ndownload数：27750  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL2-4B  \n\n**OpenGVLab/InternVL3_5-8B**  \n分类：模型  \nlike数：51  \ndownload数：7826  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3_5-8B  \n\n**OpenGVLab/InternVL3_5-GPT-OSS-20B-A4B-Preview**  \n分类：模型  \nlike数：61  \ndownload数：12332  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3_5-GPT-OSS-20B-A4B-Preview  \n\n**OpenGVLab/InternVL3_5-241B-A28B**  \n分类：模型  \nlike数：117  \ndownload数：2673  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3_5-241B-A28B  \n\n**OpenGVLab/InternVL3_5-1B**  \n分类：模型  \nlike数：12  \ndownload数：16912  \n最后更新时间：None  \nurl: https://huggingface.co/OpenGVLab/InternVL3_5-1B  \n\n**OpenGVLab/InternViT-300M-448px**  \n分类：模型  \nlike数：55  \ndownload数：2712  \n最 ...
#  Document(metadata={'source': 'HuggingFace\\OpenLoong_results.txt'}, page_content='此组织在huggingface上无like或下载数大于50的项目'),
#  Document(metadata={'source': 'HuggingFace\\rethinklab_results.txt'}, page_content='**rethinklab/Bench2Drive-Full**  \n分类：数据集  \nlike数：2  \ndownload数：13220  \n最后更新时间：2024-07-22T06:46:56.000Z  \nurl: https://huggingface.co/rethinklab/Bench2Drive-Full  \n\n**rethinklab/Bench2Drive**  \n分类：数据集  \nlike数：14  \ndownload数：6615  \n最后更新时间：2024-08-14T08:21:30.000Z  \nurl: https://huggingface.co/rethinklab/Bench2Drive  \n\n**rethinklab/Bench2Drive-Full-Sup**  \n分类：数据集  \nlike数：0  \ndownload数：4316  \n最后更新时间：2024-07-10T05:45:34.000Z  \nurl: https://huggingface.co/rethinklab/Bench2Drive-Full-Sup  \n\n**rethinklab/Bench2Drive-Map**  \n分类：数据集  \nlike数：3  \ndownload数：220  \n最后更新时间：2024-06-05T12:19:53.000Z  \nurl: https://huggingface.co/rethinklab/Bench2Drive-Map  \n\n'),
#  Document(metadata={'source': 'HuggingFace\\sensenova_results.txt'}, page_content='**sensenova/piccolo-large-zh**  \n分类：模型  \nlike数：68  \ndownload数：542  \n最后更新时间：None  \nurl: https://huggingface.co/sensenova/piccolo-large-zh  \n\n**sensenova/piccolo-large-zh-v2**  \n分类：模型  \nlike数：68  \ndownload数：17  \n最后更新时间：None  \nurl: https://huggingface.co/sensenova/piccolo-large-zh-v2  \n'),
#  Document(metadata={'source': 'HuggingFace\\stepfun-ai_results.txt'}, page_content='**GOT-OCR-2.0-hf**\n分类：模型\nlike数：212\ndownload数：60309\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/GOT-OCR-2.0-hf\n\n**GOT-OCR2_0**\n分类：模型\nlike数：1517\ndownload数：45486\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/GOT-OCR2_0\n\n**step3**\n分类：模型\nlike数：152\ndownload数：32374\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/step3\n\n**NextStep-1-Large**\n分类：模型\nlike数：92\ndownload数：3956\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/NextStep-1-Large\n\n**Step-Audio-2-mini**\n分类：模型\nlike数：204\ndownload数：2592\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/Step-Audio-2-mini\n\n**GEdit-Bench**\n分类：数据集\nlike数：20\ndownload数：2278\n最后更新时间：2025-04-29T11:28:04.000Z\nurl: https://huggingface.co/stepfun-ai/GEdit-Bench\n\n**step3-fp8**\n分类：模型\nlike数：20\ndownload数：1986\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/step3-fp8\n\n**NextStep-1-Large-Pretrain**\n分类：模型\nlike数：15\ndownload数：1377\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/NextStep-1-Large-Pretrain\n\n**NextStep-1-Large-Edit**\n分类：模型\nlike数：47\ndownload数：713\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/NextStep-1-Large-Edit\n\n**StepEval-Audio-Paralinguistic**\n分类：数据集\nlike数：6\ndownload数：442\n最后更新时间：2025-08-29T05:59:07.000Z\nurl: https://huggingface.co/stepfun-ai/StepEval-Audio-Paralinguistic\n\n**StepFun-Prover-Preview-7B**\n分类：模型\nlike数：3\ndownload数：470\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/StepFun-Prover-Preview-7B\n\n**Step-Video-T2V-Eval**\n分类：数据集\nlike数：1\ndownload数：269\n最后更新时间：2025-02-19T02:56:44.000Z\nurl: https://huggingface.co/stepfun-ai/Step-Video-T2V-Eval\n\n**Step1X-Edit**\n分类：模型\nlike数：317\ndownload数：288\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/Step1X-Edit\n\n**NextStep-1-f8ch16-Tokenizer**\n分类：模型\nlike数：14\ndownload数：288\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/NextStep-1-f8ch16-Tokenizer\n\n**StepEval-Audio-Toolcall**\n分类：数据集\nlike数：3\ndownload数：261\n最后更新时间：2025-08-29T05:57:44.000Z\nurl: https://huggingface.co/stepfun-ai/StepEval-Audio-Toolcall\n\n**StepFun-Prover-Preview-32B**\n分类：模型\nlike数：11\ndownload数：257\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/StepFun-Prover-Preview-32B\n\n**Step1X-Edit-v1p1-diffusers**\n分类：模型\nlike数：3\ndownload数：158\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/Step1X-Edit-v1p1-diffusers\n\n**StepFun-Formalizer-7B**\n分类：模型\nlike数：3\ndownload数：171\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/StepFun-Formalizer-7B\n\n**Step-Audio-TTS-3B**\n分类：模型\nlike数：190\ndownload数：125\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/Step-Audio-TTS-3B\n\n**Step1X-3D-obj-data**\n分类：数据集\nlike数：9\ndownload数：90\n最后更新时间：2025-05-22T06:25:38.000Z\nurl: https://huggingface.co/stepfun-ai/Step1X-3D-obj-data\n\n**Step-Audio-2-mini-Base**\n分类：模型\nlike数：17\ndownload数：83\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/Step-Audio-2-mini-Base\n\n**stepvideo-t2v**\n分类：模型\nlike数：469\ndownload数：77\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/stepvideo-t2v\n\n**Step-Audio-Chat**\n分类：模型\nlike数：455\ndownload数：74\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/Step-Audio-Chat\n\n**StepEval-Audio-360**\n分类：数据集\nlike数：25\ndownload数：60\n最后更新时间：2025-02-18T07:01:06.000Z\nurl: https://huggingface.co/stepfun-ai/StepEval-Audio-360\n\n**Qwen2.5-32B-DialogueReason**\n分类：模型\nlike数：12\ndownload数：58\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/Qwen2.5-32B-DialogueReason\n\n**stepvideo-ti2v**\n分类：模型\nlike数：83\ndownload数：38\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/stepvideo-ti2v\n\n**StepFun-Formalizer-32B**\n分类：模型\nlike数：4\ndownload数：103\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/StepFun-Formalizer-32B\n\n**Step1X-3D**\n分类：模型\nlike数：97\ndownload数：0\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/Step1X-3D\n\n**stepvideo-t2v-turbo**\n分类：模型\nlike数：96\ndownload数：0\n最后更新时间：None\nurl: https://huggingface.co/stepfun-ai/stepvideo-t2v-turbo\n'),
#  Document(metadata={'source': 'HuggingFace\\TigerResearch_results.txt'}, page_content='**TigerResearch/tigerbot-7b-base**  \n分类：模型  \nlike数：3  \ndownload数：1744  \n最后更新时间：None  \nurl: https://huggingface.co/TigerResearch/tigerbot-7b-base  \n\n**TigerResearch/tigerbot-70b-base-v2**  \n分类：模型  \nlike数：3  \ndownload数：1743  \n最后更新时间：None  \nurl: https://huggingface.co/TigerResearch/tigerbot-70b-base-v2  \n\n**TigerResearch/tigerbot-70b-chat-v4**  \n分类：模型  \nlike数：1  \ndownload数：1730  \n最后更新时间：None  \nurl: https://huggingface.co/TigerResearch/tigerbot-70b-chat-v4  \n\n**TigerResearch/tigerbot-7b-sft-v1**  \n分类：模型  \nlike数：13  \ndownload数：1219  \n最后更新时间：None  \nurl: https://huggingface.co/TigerResearch/tigerbot-7b-sft-v1  \n\n**TigerResearch/pretrain_zh**  \n分类：数据集  \nlike数：115  \ndownload数：1483  \n最后更新时间：2023-06-14T13:50:32.000Z  \nurl: https://huggingface.co/TigerResearch/pretrain_zh  \n\n**TigerResearch/pretrain_en**  \n分类：数据集  \nlike数：16  \ndownload数：456  \n最后更新时间：2023-05-30T10:01:55.000Z  \nurl: https://huggingface.co/TigerResearch/pretrain_en  \n\n**TigerResearch/MedCD-notes**  \n分类：数据集  \nlike数：0  \ndownload数：263  \n最后更新时间：2025-01-18T12:22:41.000Z  \nurl: https://huggingface.co/TigerResearch/MedCD-notes  \n\n**TigerResearch/tigerbot-13b-base-v1**  \n分类：模型  \nlike数：5  \ndownload数：63  \n最后更新时间：None  \nurl: https://huggingface.co/TigerResearch/tigerbot-13b-base-v1  \n\n**TigerResearch/tigerbot-kaggle-recipes-en-2k**  \n分类：数据集  \nlike数：1  \ndownload数：63  \n最后更新时间：2023-05-31T02:23:57.000Z  \nurl: https://huggingface.co/TigerResearch/tigerbot-kaggle-recipes-en-2k  \n\n**TigerResearch/sft_zh**  \n分类：数据集  \nlike数：47  \ndownload数：83  \n最后更新时间：2023-06-09T12:21:42.000Z  \nurl: https://huggingface.co/TigerResearch/sft_zh  \n\n**TigerResearch/tigerbot-kaggle-leetcodesolutions-en-2k**  \n分类：数据集  \nlike数：17  \ndownload数：60  \n最后更新时间：2023-05-31T02:01:37.000Z  \nurl: https://huggingface.co/TigerResearch/tigerbot-kaggle-leetcodesolutions-en-2k  \n\n'),
#  Document(metadata={'source': 'HuggingFace\\USTC-KnowledgeComputingLab_results.txt'}, page_content='**USTC-KnowledgeComputingLab/qmb-models**  \n分类：数据集  \nlike数：0  \ndownload数：265  \n最后更新时间：2025-07-01T17:19:41.000Z  \nurl: https://huggingface.co/USTC-KnowledgeComputingLab/qmb-models  \n\n**USTC-KnowledgeComputingLab/ElectrolyteBench**  \n分类：数据集  \nlike数：3  \ndownload数：79  \n最后更新时间：2024-10-16T03:58:37.000Z  \nurl: https://huggingface.co/USTC-KnowledgeComputingLab/ElectrolyteBench  \n\n')]

# %%
from langchain.output_parsers import CommaSeparatedListOutputParser

csvparser = CommaSeparatedListOutputParser()

format_instruction = "您的响应应该是csv格式的逗号分隔值的列表，必须是：`分类，url, 项目名称, 下载量, like数量`。你的回答必须只包含每列的标题以及csv文件中的内容，没有任何其他信息，例如\'\'\' 和 csv。"

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template(template="""
请查看以下内容并回答问题：

{context}

请分类每一个项目，相同类别的写在一起，不同类别直接空开一行。

{format_instruction}
""")

# %%
chain = prompt | model | csvparser
result = chain.invoke({"context":docs[0],"format_instruction":format_instruction})
print(result)
# Out:
# ['分类', 'url', '项目名称', '下载量', 'like数量', '数据集', 'https://huggingface.co/datasets/agibot-world/AgiBotWorld-Beta', 'agibot-world/AgiBotWorld-Beta', '37482', '34', '数据集', 'https://huggingface.co/datasets/agibot-world/AgiBotWorld-Alpha', 'agibot-world/AgiBotWorld-Alpha', '5777', '198', '数据集', 'https://huggingface.co/datasets/agibot-world/AgiBotWorldChallenge-2025', 'agibot-world/AgiBotWorldChallenge-2025', '6432', '17', '数据集', 'https://huggingface.co/datasets/agibot-world/AgiBotDigitalWorld', 'agibot-world/AgiBotDigitalWorld', '5311', '34', '数据集', 'https://huggingface.co/datasets/agibot-world/GenieSimAssets', 'agibot-world/GenieSimAssets', '2220', '12', '数据集', 'https://huggingface.co/datasets/agibot-world/EWMBench', 'agibot-world/EWMBench', '230', '0']

# %%
import csv
for doc in docs:
    chain = prompt | model | csvparser
    result = chain.invoke({"context":doc,"format_instruction":format_instruction})
    print(result)


    HEADERS = ["分类", "url", "项目名称", "下载量", "like数量"]

    def chunk(lst, n):
        for i in range(0, len(lst), n):
            yield lst[i:i+n]

    with open('huggingface_csv.csv', 'a', encoding='utf-8', newline='') as f:
        writer = csv.writer(f)
        # writer.writerow(HEADERS)
        for row in chunk(result[len(HEADERS):], len(HEADERS)):
            if len(row) < len(HEADERS):  # 末尾不满一行时补空
                row += [''] * (len(HEADERS) - len(row))
            writer.writerow(row)
        writer.writerow("")
# Out:
# ['分类', 'url', '项目名称', '下载量', 'like数量', '数据集', 'https://huggingface.co/datasets/agibot-world/AgiBotWorld-Beta', 'agibot-world/AgiBotWorld-Beta', '37482', '34', '数据集', 'https://huggingface.co/datasets/agibot-world/AgiBotWorld-Alpha', 'agibot-world/AgiBotWorld-Alpha', '5777', '198', '数据集', 'https://huggingface.co/datasets/agibot-world/AgiBotWorldChallenge-2025', 'agibot-world/AgiBotWorldChallenge-2025', '6432', '17', '数据集', 'https://huggingface.co/datasets/agibot-world/AgiBotDigitalWorld', 'agibot-world/AgiBotDigitalWorld', '5311', '34', '数据集', 'https://huggingface.co/datasets/agibot-world/GenieSimAssets', 'agibot-world/GenieSimAssets', '2220', '12', '数据集', 'https://huggingface.co/datasets/agibot-world/EWMBench', 'agibot-world/EWMBench', '230', '0']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '模型', 'https://huggingface.co/ECNU-CILab/ArtAug-lora-FLUX.1dev-v1', 'ECNU-CILab/ArtAug-lora-FLUX.1dev-v1', '95', '8', '模型', 'https://huggingface.co/ECNU-CILab/ExVideo-SVD-128f-v1', 'ECNU-CILab/ExVideo-SVD-128f-v1', '0', '61']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '数据集', 'https://huggingface.co/datasets/FourierIntelligence/ActionNet', 'FourierIntelligence/ActionNet', '1540', '6']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '数据集', 'https://huggingface.co/fudan-generative-ai/champ_trainning_sample', 'fudan-generative-ai/champ_trainning_sample', '978', '6', '数据集', 'https://huggingface.co/fudan-generative-ai/champ_motions_example', 'fudan-generative-ai/champ_motions_example', '337', '2', '数据集', 'https://huggingface.co/fudan-generative-ai/hallo3_training_data', 'fudan-generative-ai/hallo3_training_data', '123', '7', '模型', 'https://huggingface.co/fudan-generative-ai/hallo2', 'fudan-generative-ai/hallo2', '0', '129', '模型', 'https://huggingface.co/fudan-generative-ai/hallo', 'fudan-generative-ai/hallo', '0', '96', '模型', 'https://huggingface.co/fudan-generative-ai/hallo3', 'fudan-generative-ai/hallo3', '0', '62']
# ['分类', 'url', '项目名称', '下载量', 'like数量  ', '数据集', 'https://huggingface.co/Infinigence/LVEval', 'Infinigence/LVEval', '4637', '13  ', '模型', 'https://huggingface.co/Infinigence/Megrez-3B-Instruct', 'Infinigence/Megrez-3B-Instruct', '1199', '32  ', '模型', 'https://huggingface.co/Infinigence/Megrez-3B-Omni', 'Infinigence/Megrez-3B-Omni', '18', '134']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '模型', 'https://huggingface.co/infly/inf-retriever-v1', 'infly/inf-retriever-v1', '15612', '37', '模型', 'https://huggingface.co/infly/inf-retriever-v1-1.5b', 'infly/inf-retriever-v1-1.5b', '5996', '42', '模型', 'https://huggingface.co/infly/INF-ORM-Llama3.1-70B', 'infly/INF-ORM-Llama3.1-70B', '3027', '26', '模型', 'https://huggingface.co/infly/OpenCoder-8B-Instruct', 'infly/OpenCoder-8B-Instruct', '1666', '196', '模型', 'https://huggingface.co/infly/OpenCoder-1.5B-Instruct', 'infly/OpenCoder-1.5B-Instruct', '1228', '42', '模型', 'https://huggingface.co/infly/OpenCoder-1.5B-Base', 'infly/OpenCoder-1.5B-Base', '1176', '22', '模型', 'https://huggingface.co/infly/OpenCoder-8B-Base', 'infly/OpenCoder-8B-Base', '1166', '28', '模型', 'https://huggingface.co/infly/inf-wse-v2-base-zh', 'infly/inf-wse-v2-base-zh', '834', '3', '模型', 'https://huggingface.co/infly/inf-rl-qwen-coder-32b-2746', 'infly/inf-rl-qwen-coder-32b-2746', '155', '2', '模型', 'https://huggingface.co/infly/inf-o1-pi0', 'infly/inf-o1-pi0', '52', '8', '数据集', 'https://huggingface.co/infly/Infinity-Doc-55K', 'infly/Infinity-Doc-55K', '172', '6', '数据集', 'https://huggingface.co/infly/INF-ORM-Preference-Magnitude-80K', 'infly/INF-ORM-Preference-Magnitude-80K', '102', '9']
# ['分类', 'url', '项目名称', '下载量', 'like数量  ', '模型（如大语言模型，多模态模型等）', 'https://huggingface.co/MemTensor/MemOperator-0.6B', 'MemTensor/MemOperator-0.6B', '193', '1']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '模型', 'https://huggingface.co/MiniMaxAI/MiniMax-VL-01', 'MiniMaxAI/MiniMax-VL-01', '103864', '277', '模型', 'https://huggingface.co/MiniMaxAI/MiniMax-Text-01', 'MiniMaxAI/MiniMax-Text-01', '3423', '644', '模型', 'https://huggingface.co/MiniMaxAI/MiniMax-Text-01-hf', 'MiniMaxAI/MiniMax-Text-01-hf', '16497', '6', '模型', 'https://huggingface.co/MiniMaxAI/MiniMax-M1-40k', 'MiniMaxAI/MiniMax-M1-40k', '26365', '175', '模型', 'https://huggingface.co/MiniMaxAI/MiniMax-M1-80k', 'MiniMaxAI/MiniMax-M1-80k', '994', '671', '模型', 'https://huggingface.co/MiniMaxAI/SynLogic-7B', 'MiniMaxAI/SynLogic-7B', '134', '20', '模型', 'https://huggingface.co/MiniMaxAI/SynLogic-Mix-3-32B', 'MiniMaxAI/SynLogic-Mix-3-32B', '114', '12', '模型', 'https://huggingface.co/MiniMaxAI/SynLogic-32B', 'MiniMaxAI/SynLogic-32B', '104', '11', '模型', 'https://huggingface.co/MiniMaxAI/MiniMax-M1-80k-hf', 'MiniMaxAI/MiniMax-M1-80k-hf', '101', '3', '模型', 'https://huggingface.co/MiniMaxAI/MiniMax-M1-40k-hf', 'MiniMaxAI/MiniMax-M1-40k-hf', '65', '5', '数据集', 'https://huggingface.co/MiniMaxAI/TTS-Multilingual-Test-Set', 'MiniMaxAI/TTS-Multilingual-Test-Set', '515', '21', '数据集', 'https://huggingface.co/MiniMaxAI/SynLogic', 'MiniMaxAI/SynLogic', '477', '92', '数据集', 'https://huggingface.co/MiniMaxAI/MR-NIAH', 'MiniMaxAI/MR-NIAH', '121', '3']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '模型', 'https://huggingface.co/OpenGVLab/InternVL2_5-26B', 'OpenGVLab/InternVL2_5-26B', '193035', '31', '模型', 'https://huggingface.co/OpenGVLab/InternVL3-14B', 'OpenGVLab/InternVL3-14B', '933553', '73', '模型', 'https://huggingface.co/OpenGVLab/InternVL2-2B', 'OpenGVLab/InternVL2-2B', '939404', '73', '模型', 'https://huggingface.co/OpenGVLab/InternVL3-38B', 'OpenGVLab/InternVL3-38B', '178735', '42', '模型', 'https://huggingface.co/OpenGVLab/InternVL3-1B', 'OpenGVLab/InternVL3-1B', '85243', '72', '模型', 'https://huggingface.co/OpenGVLab/InternVL3-78B', 'OpenGVLab/InternVL3-78B', '441658', '216', '模型', 'https://huggingface.co/OpenGVLab/InternVL3-8B', 'OpenGVLab/InternVL3-8B', '287542', '95', '模型', 'https://huggingface.co/OpenGVLab/InternVL2-1B', 'OpenGVLab/InternVL2-1B', '189558', '77', '模型', 'https://huggingface.co/OpenGVLab/InternVL3-2B', 'OpenGVLab/InternVL3-2B', '49399', '36', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-4B-AWQ', 'OpenGVLab/InternVL3_5-4B-AWQ', '156138', '7', '模型', 'https://huggingface.co/OpenGVLab/InternVL2-8B', 'OpenGVLab/InternVL2-8B', '37271', '177', '模型', 'https://huggingface.co/OpenGVLab/InternVL2_5-2B', 'OpenGVLab/InternVL2_5-2B', '41163', '29', '模型', 'https://huggingface.co/OpenGVLab/InternVL2_5-4B', 'OpenGVLab/InternVL2_5-4B', '47375', '52', '模型', 'https://huggingface.co/OpenGVLab/InternVL2_5-8B', 'OpenGVLab/InternVL2_5-8B', '34893', '93', '模型', 'https://huggingface.co/OpenGVLab/InternViT-300M-448px-V2_5', 'OpenGVLab/InternViT-300M-448px-V2_5', '42806', '44', '模型', 'https://huggingface.co/OpenGVLab/InternVideo2_5_Chat_8B', 'OpenGVLab/InternVideo2_5_Chat_8B', '29344', '82', '模型', 'https://huggingface.co/OpenGVLab/InternVL2-40B', 'OpenGVLab/InternVL2-40B', '12448', '94', '模型', 'https://huggingface.co/OpenGVLab/InternVL2_5-1B', 'OpenGVLab/InternVL2_5-1B', '16673', '61', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-30B-A3B', 'OpenGVLab/InternVL3_5-30B-A3B', '23024', '31', '模型', 'https://huggingface.co/OpenGVLab/pvt_v2_b0', 'OpenGVLab/pvt_v2_b0', '24321', '2', '模型', 'https://huggingface.co/OpenGVLab/InternVL2-26B', 'OpenGVLab/InternVL2-26B', '23989', '118', '模型', 'https://huggingface.co/OpenGVLab/InternVL2-4B', 'OpenGVLab/InternVL2-4B', '27750', '53', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-8B', 'OpenGVLab/InternVL3_5-8B', '7826', '51', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-GPT-OSS-20B-A4B-Preview', 'OpenGVLab/InternVL3_5-GPT-OSS-20B-A4B-Preview', '12332', '61', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-241B-A28B', 'OpenGVLab/InternVL3_5-241B-A28B', '2673', '117', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-1B', 'OpenGVLab/InternVL3_5-1B', '16912', '12', '模型', 'https://huggingface.co/OpenGVLab/InternViT-300M-448px', 'OpenGVLab/InternViT-300M-448px', '2712', '55', '模型', 'https://huggingface.co/OpenGVLab/Mini-InternVL-Chat-2B-V1-5', 'OpenGVLab/Mini-InternVL-Chat-2B-V1-5', '10106', '72', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-38B', 'OpenGVLab/InternVL3_5-38B', '6596', '24', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-4B', 'OpenGVLab/InternVL3_5-4B', '4042', '20', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-14B', 'OpenGVLab/InternVL3_5-14B', '3643', '18', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-2B', 'OpenGVLab/InternVL3_5-2B', '7707', '10', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-1B-Instruct', 'OpenGVLab/InternVL3_5-1B-Instruct', '2920', '5', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-14B-Instruct', 'OpenGVLab/InternVL3_5-14B-Instruct', '1706', '6', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-2B-Instruct', 'OpenGVLab/InternVL3_5-2B-Instruct', '10865', '2', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-4B-Instruct', 'OpenGVLab/InternVL3_5-4B-Instruct', '908', '2', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-30B-A3B-Instruct', 'OpenGVLab/InternVL3_5-30B-A3B-Instruct', '558', '10', '模型', 'https://huggingface.co/OpenGVLab/InternVL3_5-241B-A28 ...
# ['分类', 'url', '项目名称', '下载量', 'like数量', '无热门项目', '', '', '', '']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '数据集', 'https://huggingface.co/rethinklab/Bench2Drive-Full', 'rethinklab/Bench2Drive-Full', '13220', '2', '数据集', 'https://huggingface.co/rethinklab/Bench2Drive', 'rethinklab/Bench2Drive', '6615', '14', '数据集', 'https://huggingface.co/rethinklab/Bench2Drive-Full-Sup', 'rethinklab/Bench2Drive-Full-Sup', '4316', '0', '数据集', 'https://huggingface.co/rethinklab/Bench2Drive-Map', 'rethinklab/Bench2Drive-Map', '220', '3']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '模型', 'https://huggingface.co/sensenova/piccolo-large-zh', 'sensenova/piccolo-large-zh', '542', '68', '模型', 'https://huggingface.co/sensenova/piccolo-large-zh-v2', 'sensenova/piccolo-large-zh-v2', '17', '68']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '模型', 'https://huggingface.co/stepfun-ai/GOT-OCR-2.0-hf', 'GOT-OCR-2.0-hf', '60309', '212', '模型', 'https://huggingface.co/stepfun-ai/GOT-OCR2_0', 'GOT-OCR2_0', '45486', '1517', '模型', 'https://huggingface.co/stepfun-ai/step3', 'step3', '32374', '152', '模型', 'https://huggingface.co/stepfun-ai/NextStep-1-Large', 'NextStep-1-Large', '3956', '92', '模型', 'https://huggingface.co/stepfun-ai/Step-Audio-2-mini', 'Step-Audio-2-mini', '2592', '204', '模型', 'https://huggingface.co/stepfun-ai/step3-fp8', 'step3-fp8', '1986', '20', '模型', 'https://huggingface.co/stepfun-ai/NextStep-1-Large-Pretrain', 'NextStep-1-Large-Pretrain', '1377', '15', '模型', 'https://huggingface.co/stepfun-ai/NextStep-1-Large-Edit', 'NextStep-1-Large-Edit', '713', '47', '模型', 'https://huggingface.co/stepfun-ai/StepFun-Prover-Preview-7B', 'StepFun-Prover-Preview-7B', '470', '3', '模型', 'https://huggingface.co/stepfun-ai/Step1X-Edit', 'Step1X-Edit', '288', '317', '模型', 'https://huggingface.co/stepfun-ai/NextStep-1-f8ch16-Tokenizer', 'NextStep-1-f8ch16-Tokenizer', '288', '14', '模型', 'https://huggingface.co/stepfun-ai/StepFun-Prover-Preview-32B', 'StepFun-Prover-Preview-32B', '257', '11', '模型', 'https://huggingface.co/stepfun-ai/Step1X-Edit-v1p1-diffusers', 'Step1X-Edit-v1p1-diffusers', '158', '3', '模型', 'https://huggingface.co/stepfun-ai/StepFun-Formalizer-7B', 'StepFun-Formalizer-7B', '171', '3', '模型', 'https://huggingface.co/stepfun-ai/Step-Audio-TTS-3B', 'Step-Audio-TTS-3B', '125', '190', '模型', 'https://huggingface.co/stepfun-ai/Step-Audio-2-mini-Base', 'Step-Audio-2-mini-Base', '83', '17', '模型', 'https://huggingface.co/stepfun-ai/stepvideo-t2v', 'stepvideo-t2v', '77', '469', '模型', 'https://huggingface.co/stepfun-ai/Step-Audio-Chat', 'Step-Audio-Chat', '74', '455', '模型', 'https://huggingface.co/stepfun-ai/Qwen2.5-32B-DialogueReason', 'Qwen2.5-32B-DialogueReason', '58', '12', '模型', 'https://huggingface.co/stepfun-ai/stepvideo-ti2v', 'stepvideo-ti2v', '38', '83', '模型', 'https://huggingface.co/stepfun-ai/StepFun-Formalizer-32B', 'StepFun-Formalizer-32B', '103', '4', '模型', 'https://huggingface.co/stepfun-ai/Step1X-3D', 'Step1X-3D', '0', '97', '模型', 'https://huggingface.co/stepfun-ai/stepvideo-t2v-turbo', 'stepvideo-t2v-turbo', '0', '96', '数据集', 'https://huggingface.co/stepfun-ai/GEdit-Bench', 'GEdit-Bench', '2278', '20', '数据集', 'https://huggingface.co/stepfun-ai/StepEval-Audio-Paralinguistic', 'StepEval-Audio-Paralinguistic', '442', '6', '数据集', 'https://huggingface.co/stepfun-ai/Step-Video-T2V-Eval', 'Step-Video-T2V-Eval', '269', '1', '数据集', 'https://huggingface.co/stepfun-ai/StepEval-Audio-Toolcall', 'StepEval-Audio-Toolcall', '261', '3', '数据集', 'https://huggingface.co/stepfun-ai/Step1X-3D-obj-data', 'Step1X-3D-obj-data', '90', '9', '数据集', 'https://huggingface.co/stepfun-ai/StepEval-Audio-360', 'StepEval-Audio-360', '60', '25']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '模型', 'https://huggingface.co/TigerResearch/tigerbot-7b-base', 'TigerResearch/tigerbot-7b-base', '1744', '3', '模型', 'https://huggingface.co/TigerResearch/tigerbot-70b-base-v2', 'TigerResearch/tigerbot-70b-base-v2', '1743', '3', '模型', 'https://huggingface.co/TigerResearch/tigerbot-70b-chat-v4', 'TigerResearch/tigerbot-70b-chat-v4', '1730', '1', '模型', 'https://huggingface.co/TigerResearch/tigerbot-7b-sft-v1', 'TigerResearch/tigerbot-7b-sft-v1', '1219', '13', '模型', 'https://huggingface.co/TigerResearch/tigerbot-13b-base-v1', 'TigerResearch/tigerbot-13b-base-v1', '63', '5', '数据集', 'https://huggingface.co/TigerResearch/pretrain_zh', 'TigerResearch/pretrain_zh', '1483', '115', '数据集', 'https://huggingface.co/TigerResearch/pretrain_en', 'TigerResearch/pretrain_en', '456', '16', '数据集', 'https://huggingface.co/TigerResearch/MedCD-notes', 'TigerResearch/MedCD-notes', '263', '0', '数据集', 'https://huggingface.co/TigerResearch/tigerbot-kaggle-recipes-en-2k', 'TigerResearch/tigerbot-kaggle-recipes-en-2k', '63', '1', '数据集', 'https://huggingface.co/TigerResearch/sft_zh', 'TigerResearch/sft_zh', '83', '47', '数据集', 'https://huggingface.co/TigerResearch/tigerbot-kaggle-leetcodesolutions-en-2k', 'TigerResearch/tigerbot-kaggle-leetcodesolutions-en-2k', '60', '17']
# ['分类', 'url', '项目名称', '下载量', 'like数量', '数据集', 'https://huggingface.co/USTC-KnowledgeComputingLab/qmb-models', 'USTC-KnowledgeComputingLab/qmb-models', '265', '0', '数据集', 'https://huggingface.co/USTC-KnowledgeComputingLab/ElectrolyteBench', 'USTC-KnowledgeComputingLab/ElectrolyteBench', '79', '3']
